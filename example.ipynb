# %%
1+2*3*4*5/6**3+7+7-9+10
# Out:
# 16.555555555555557

# %%
1+2*(3*4*5/6)**3+7+7-9+10
# Out:
# 2016.0

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %%
x = "awesome"
def myfunc():
  global x
  x = "fantastic"
myfunc()
print("Python is "+ x)
# Out:
# Python is fantastic

# %%
10//9
# Out:
# 1

# %%
l1=[2,3]
print(len(l1))
# Out:
# 2

# %%
thislist = ["apple", "banana", 
"cherry", "orange", "kiwi", 
"melon", "mango"]
print(thislist[-4:-1])
# Out:
# ['orange', 'kiwi', 'melon']
